# %%
# !wget https://github.com/javierherrera1996/IntroMachineLearning/raw/refs/heads/main/TercerCorte/amazon.csv.zip
# !unzip amazon.csv.zip
# Out:
# --2025-06-05 04:51:09--  https://github.com/javierherrera1996/IntroMachineLearning/raw/refs/heads/main/TercerCorte/amazon.csv.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/javierherrera1996/IntroMachineLearning/refs/heads/main/TercerCorte/amazon.csv.zip [following]
# --2025-06-05 04:51:10--  https://raw.githubusercontent.com/javierherrera1996/IntroMachineLearning/refs/heads/main/TercerCorte/amazon.csv.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2043633 (1.9M) [application/zip]
# Saving to: ‘amazon.csv.zip.2’
#
# ...

# %%
import os
os.environ["OPENAI_API_KEY"]= "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"

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
import openai
openai.api_key = "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"

# %%
import pandas as pd
df = pd.read_csv('amazon.csv')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df["main_category"] = df["category"].apply(lambda x: x.split("|")[0] if pd.notna(x) else "")

# %%
df.shape
# Out:
# (1465, 16)

# %% [markdown]
# ## 🧪 Preguntas a desarrollar paso a paso

# %% [markdown]
# ### 1. Inspección y limpieza de la base de datos
# - ¿Qué columnas son útiles para este análisis?
# - ¿Cómo podrías limpiar los valores nulos o inconsistentes?
# - Extrae el primer nivel de categoría del producto.

# %% [markdown]
# Las columnas mas importantes son : product_name , review_content , rating , discounted_price , actual_price y category

# %%
df = df.dropna(subset=['review_content'])

# %% [markdown]
# con el codigo de arriba podriamos eliminar filas sin reseñas

# %%
df["main_category"] = df["category"].apply(lambda x: x.split("|")[0] if pd.notna(x) else "")

# %%
df["discounted_price"] = df["discounted_price"].str.replace("₹", "").str.replace(",", "").astype(float)
df["actual_price"] = df["actual_price"].str.replace("₹", "").str.replace(",", "").astype(float)
df["discount_percentage"] = df["discount_percentage"].str.replace("%", "").astype(float)
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

# %%
df["review_count"] = df["review_id"].apply(lambda x: len(str(x).split(",")) if pd.notna(x) else 0)

# %%
import re

def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)
    text = re.sub(r"\s+", " ", text)
    return text.strip()

if "clean_review" not in df.columns:
    df["clean_review"] = df["review_content"].apply(clean_text)

# %% [markdown]
# ### 2. Exploración preliminar
# - ¿Cómo se distribuyen las calificaciones (`rating`)?
# - ¿Cuáles son las 10 categorías con más reseñas?
# - ¿Qué productos tienen mayor número de reseñas?

# %%
print("Total reseñas:", df["review_count"].sum())
print("Columnas clave:", df[["product_name", "rating", "review_title", "review_content"]].shape)
# Out:
# Total reseñas: 11503
# Columnas clave: (1465, 4)

# %%
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

# %%
rating_dist = df["rating"].value_counts().sort_index()

# %%
print(" Distribución de calificaciones:")
print(rating_dist)
# Out:
#  Distribución de calificaciones:
# rating
# 2.0      1
# 2.3      1
# 2.6      1
# 2.8      2
# 2.9      1
# 3.0      4
# 3.1      4
# 3.2      2
# 3.3     16
# 3.4     10
# 3.5     26
# 3.6     35
# 3.7     42
# 3.8     86
# 3.9    123
# 4.0    181
# 4.1    244
# 4.2    228
# 4.3    230
# 4.4    123
# 4.5     75
# 4.6     17
# 4.7      6
# 4.8      3
# 5.0      3
# Name: count, dtype: int64

# %% [markdown]
# la distribucion de las calificaciones se concentra entre 3.5 y 4.5
#
# las mas rerseñadas son : COMPUTERS & A , ELECTRONICS, HOME & K, BABY, INDUSTRIAL & ACCESORIES, HEALTH & PC, SPORTS & OUTDOORS, MUSICAL I, OFFICE P
#
# LOS PRODUCTOS MAS RESEÑADOS SON
# Wayona Nylon Braided USB to Lightning Fast Charging Cable
# Belkin Essential Series 4-Socket Surge Protector
# Portronics Konnect L 20W PD Quick Charge Type-C Cable
# Canon PIXMA E477 All-in-One Wireless Printer

# %% [markdown]
# ### 3. Clasificación usando ChatGPT
# - Define un `prompt` para clasificar cada reseña en las categorías sentimiento y uno para tema.
# - ¿Qué función usarás para conectar con ChatGPT?
# - Clasifica al menos 2.000 reseñas y añade columnas `sentimiento` y `tema`.

# %% [markdown]
# identifica el tema principal del siguiente comentario como: calidad, precio, funcionalidad, entrega, servicio y durabilidad

# %% [markdown]
# califica el siguiente texto como "positivo", "negativo" o "neutral" segun el sentimiento general

# %%
def call_llm(prompt):
  response = client.responses.create(
  model="gpt-4o-mini",
  input=prompt
)
  return response.output_text

# %%
import openai
openai.api_key = "OPENAI_API_KEY"
def clasificar_con_chatgpt(texto, tipo="sentimiento"):
    if tipo == "sentimiento":
        prompt = f'Clasifica el siguiente texto como "positivo", "negativo" o "neutral":\n\nTexto: {texto}\nRespuesta:'
    elif tipo == "tema":
        prompt = f"Identifica el tema principal del siguiente comentario. Puede ser: calidad, precio, funcionalidad, entrega, compatibilidad, servicio, durabilidad.\n\nTexto: {texto}\nRespuesta:"
    else:
        return "tipo inválido"

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )
    return response.choices[0].message["content"].strip().lower()

# %%
df = df.dropna(subset=["clean_review"]).reset_index(drop=True)

# %%
subset = df.head(2000).copy()

# %%
subset["sentimiento"] = ""
subset["tema"] = ""

# %%
for i in range(len(subset)):
    texto = subset.loc[i, "clean_review"]
    subset.at[i, "sentimiento"] = clasificar_con_chatgpt(texto, "sentimiento")
    subset.at[i, "tema"] = clasificar_con_chatgpt(texto, "tema")
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# <ipython-input-64-e3405db101c3> in <cell line: 0>()
#       1 for i in range(len(subset)):
#       2     texto = subset.loc[i, "clean_review"]
# ----> 3     subset.at[i, "sentimiento"] = clasificar_con_chatgpt(texto, "sentimiento")
#       4     subset.at[i, "tema"] = clasificar_con_chatgpt(texto, "tema")
#       5
#
# <ipython-input-53-5578e8563582> in clasificar_con_chatgpt(texto, tipo)
#       9         return "tipo inválido"
#      10
# ---> 11     response = openai.ChatCompletion.create(
#      12         model="gpt-4",
#      13         messages=[{"role": "user", "content": prompt}],
#
# /usr/local/lib/python3.11/dist-packages/openai/lib/_old_api.py in __call__(self, *_args, **_kwargs)
#      37
#      38     def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39         raise APIRemovedInV1(symbol=self._symbol)
# ...

# %% [markdown]
# ### 4. Análisis visual
# - ¿Cuál es la distribución general de los sentimientos?
# - ¿Qué categorías tienen más reseñas muy negativas o muy positivas?
# - ¿Qué temas aparecen más en reseñas negativas?
# - Usa mapas de calor y gráficos de barras para responder.

# %% [markdown]
# ### 5. Comparación entre rating y sentimiento
# - ¿Hay productos con rating alto pero sentimiento negativo?
# - ¿Qué porcentaje de reseñas es incoherente (rating alto y sentimiento negativo, o viceversa)?
# - ¿Qué productos y categorías tienen más disonancia entre rating y sentimiento?

# %% [markdown]
# ### 6. Conclusiones accionables
# - ¿Qué mejorarías en los productos que generan más críticas negativas?
# - ¿Qué temas positivos puedes usar para campañas de marketing?
# - Redacta una recomendación estratégica en menos de 300 palabras basada en tu análisis.

# %% [markdown]
# invertiria en control de calidad, agregaria manuales de uso y garantía en el empaque, Mejorararia pruebas de uso antes de despacho, Optimizaria sensibilidad de interfaces táctiles en smartwatches.

# %% [markdown]
# Hablaria de la relación calidad–precio: muchos productos cumplen con lo prometido por un precio accesible, y de la compatibilidad con múltiples dispositivos: cables y cargadores bien valorados funcionan con iPhone, Android, autos, laptops, etc.

# %% [markdown]
# tras revisar las reseñas de productos tecnológicos en Amazon, encontramos dos cosas clave. La primera es que a los usuarios les encanta cuando un producto tiene buen precio, es fácil de usar y funciona con varios dispositivos. Estas son cualidades que definitivamente se deben destacar en la comunicación y en campañas de marketing, porque muestran que el producto cumple lo que promete.
#
# Por otro lado, también se repiten varias quejas: productos que se dañan rápido, fallos desde el primer uso, olores extraños y la falta de información sobre garantía o servicio al cliente. Esto sugiere que hay oportunidades claras de mejora en el control de calidad y en la atención posventa.
#
# Lo ideal sería fortalecer el proceso de fabricación para evitar errores, incluir instrucciones claras y canales de contacto, y al mismo tiempo seguir resaltando lo bueno que ya tienen los productos, como la compatibilidad o la duración de la batería. Con estos ajustes, es muy probable que la percepción del usuario mejore, lo que se puede traducir en más ventas, mejores reseñas y una marca más fuerte
